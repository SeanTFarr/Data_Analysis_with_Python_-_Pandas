# %% [markdown]
# ### Timeline code

# %%
 # %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

# %%
#lists
names =["Adam born", "Adam died", "Seth born", "Seth died",
       "Enosh born", "Enosh died", "Kenan born", "Kenan died",
       "Mahalalel born", "Mahalalel died", "Jared born", "Jared died",
       "Enoch born", "Enoch died", "Methuselah born", "Methuselah died",
       "Lamech born", "Lamech died", "Noah born", "Noah died",
       "Shem born", "Shem died", "Arpachshad born", "Arpachshad died",
       "Shelah born", "Shelah died", "Eber born", "Eber died",
       "Peleg born", "Peleg died", "Reu born", "Reu died",
       "Serug born", "Serug died", "Nahor born", "Nahor died",
       "Terah born", "Terah died", "Abraham born", "Abraham died",
       "Isaac born", "Isaac died", "Jacob born", "Jacob died"]

dates = ["-4000-01-01", "-3070-01-01", "-3870-01-01", "-2958-01-01",
        "-3765-01-01", "-2860-01-01", "-3675-01-01", "-2765-01-01",
        "-3605-01-01", "-2710-01-01", "-3540-01-01", "-2578-01-01",
        "-3378-01-01", "-3013-01-01", "-3313-01-01", "-2344-01-01",
        "-3126-01-01", "-2349-01-01", "-2944-01-01", "-1994-01-01",
        "-2444-01-01", "-1842-01-01", "-2342-01-01", "-1904-01-01",
        "-2307-01-01", "-1874-01-01", "-2277-01-01", "-1813-01-01",
        "-2243-01-01", "-2004-01-01", "-2213-01-01", "-1974-01-01",
        "-2181-01-01", "-1951-01-01", "-2151-01-01", "-2003-01-01",
        "-2122-01-01", "-1917-01-01", "-2052-01-01", "-1877-01-01",
        "-1952-01-01", "-1772-01-01", "-1892-01-01", "-1745-01-01"]
dates = [datetime.strptime(d,"-%Y-%m-%d") for d in dates]

# %%
# Choose some nice levels
levels = np.tile([.4, -.4, .3, -.3, .2, -.2, .1, -.1 ],
                 int(len(dates)/4))[:len(dates)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(30, 12), layout="constrained")
ax.set(title="Genesis Record of Man")

ax.vlines(dates, 0, levels, color="tab:red")  # The vertical stems.
ax.plot(dates, np.zeros_like(dates), "-o",
        color="k", markerfacecolor="w")  # Baseline and markers on it.

# annotate lines
for d, l, r in zip(dates, levels, names):
    ax.annotate(r, xy=(d, l),
                xytext=(0, np.sign(l)*3), textcoords="offset points",
                horizontalalignment="center",
                verticalalignment="bottom" if l > 0 else "top",
               rotation=90)
    
# remove y-axis and spines
ax.yaxis.set_visible(False)
ax.spines[["left", "top", "right"]].set_visible(False)

ax.xaxis.set_major_locator(mdates.YearLocator(100))
plt.setp(ax.get_xticklabels(), rotation=30, ha="right")


ax.margins(y=0.1)
#plt.savefig("Gen_Time.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="3000.0000794728617">

# %%
# # annotate lines
# for d, l, r in zip(years, levels, names):
#     ax.annotate(r, xy=(d, l),
#                 xytext=(-3, np.sign(l)*3), textcoords="offset points",
#                 horizontalalignment="right",
#                 verticalalignment="bottom" if l > 0 else "top")

# %%
# format x-axis with 4-month intervals
#ax.xaxis.set_major_locator(mdates.MonthLocator(interval=4))
#ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
#plt.setp(ax.get_xticklabels(), rotation=30, ha="right")

# %%
# # remove y-axis and spines
# ax.yaxis.set_visible(False)
# ax.spines[["left", "top", "right"]].set_visible(False)

# %%
# ax.margins(y=0.1)
# plt.show()

# %%
#plt.show()
